# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
# meta_train_df = pd.read_excel('meta_train.xlsx')
# meta_test_df = pd.read_excel('meta_test.xlsx')
# attn_diff_df = pd.read_excel('attn_diff.xlsx')

# %%
# fig1, (ax1) = plt.subplots(1, 1, figsize=(7,5))
# sns.barplot(x="attn_type", y="avg_attn_diff",
#                 hue="model", data=attn_diff_df, ax=ax1)
# plt.ylim(0, 0.18)    # 设置纵坐标范围
# plt.tick_params(labelsize=14)    # 设置坐标刻度字体大小
# legend = plt.legend(loc = 1, title=None, framealpha=1, fontsize='x-large')
# ax1.set_xlabel(xlabel='attn_type', fontsize=18)
# ax1.set_ylabel(ylabel='avg_attn_diff',fontsize=18)
# plt.tight_layout()    # 避免标签超出显示范围
# plt.savefig('attn_diff.eps', dpi=600, format='eps')

# %%
attn_diff_df = pd.read_excel('attn_diff_3.xlsx')
sns.set_theme(style="whitegrid", font_scale=1.35)

# fig1, (ax1) = plt.subplots(1, 1, figsize=(7,5))
g = sns.catplot(x=" ", y="Avg Attention Difference",
                hue="Method", col="Stage", kind="bar",
                data=attn_diff_df, 
                height=5, aspect=.65, )
#                 legend=True, legend_out=True)
plt.ylim(0, 0.15)    # 设置纵坐标范围
# plt.tick_params(labelsize=14)    # 设置坐标刻度字体大小
# plt.tight_layout()    # 避免标签超出显示范围
plt.savefig('attn_diff.eps', dpi=600, format='eps')
# plt.savefig('attn_diff.png', dpi=600, format='png')

# %%
'''
matplotlib 画矢量图生成 .eps 文件  =>  命令行 epstopdf  =>  https://pdfresizer.com/crop  裁剪 pdf 白边  =>  导入
'''
